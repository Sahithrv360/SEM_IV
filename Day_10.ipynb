# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
data = pd.read_csv('ultimate_student_productivity_dataset_5000.csv')
data['pass'] = np.where(data['exam_score'] >= 24, 1,0)
X = data.select_dtypes(include = np.number)
X.drop(columns=['exam_score','student_id','pass'],inplace=True)
y = data['pass']
print(y.head())
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    1
# Name: pass, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
mlp = MLPClassifier(hidden_layer_sizes=(10,10))

mlp.fit(X_train, y_train)
y_pred = mlp.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.888
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.92      0.92       668
#            1       0.84      0.82      0.83       332
#
#     accuracy                           0.89      1000
#    macro avg       0.88      0.87      0.87      1000
# weighted avg       0.89      0.89      0.89      1000
# C:\Users\sahit\.conda\envs\ml\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
mlp = MLPClassifier()

mlp.fit(X_train, y_train)
y_pred = mlp.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.895
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92       668
#            1       0.86      0.82      0.84       332
#
#     accuracy                           0.90      1000
#    macro avg       0.89      0.88      0.88      1000
# weighted avg       0.89      0.90      0.89      1000
# C:\Users\sahit\.conda\envs\ml\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
